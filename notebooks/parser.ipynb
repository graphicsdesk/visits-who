# %% [markdown]
# ## Guiding questions
#
# Where does Columbia Visits You visit?

# %%
from bs4 import BeautifulSoup
from datetime import datetime

import os
import requests
import re
import json

# %%
# DUPLICATE OF THE VERSION IN SCRAPER

EVENTS_URLS = {
    'brown': 'https://apply.college.brown.edu/portal/brown-near-you?c=&country=',
    'columbia': 'https://apply.college.columbia.edu/portal/register?c=&country=',
    'mit': 'https://mitadmissions.org/visit/mit-visits-you/fall-travel',
    'princeton': 'https://apply.princeton.edu/portal/upcoming_events?c=&country=',
    'stanford': 'https://apply.stanford.edu/portal/stanfordinyourarea?c=&country=',
    'uchicago': 'https://prospects.uchicago.edu/register/?c=&country=',
    'upenn': 'https://key.admissions.upenn.edu/portal/penn-in-your-town?c=&country=',
    'yale': 'https://apps.admissions.yale.edu/portal/events?c=&country=',    
    'eco': 'http://www.exploringcollegeoptions.org/',
}

# %%
documents = {}

for directory in os.listdir('../documents'):
    if directory == '.DS_Store':
        continue
    documents[directory] = sorted(
        [f for f in os.listdir('../documents/' + directory) if EVENT_FNAME_REGEX.match(f) is not None]
    )

# %%
# Returns event hrefs from a document
def get_event_hrefs(fname, uni):

    # soup file contents

    html = open('../documents/' + fname, 'r').read()
    soup = BeautifulSoup(html)
    # Find and store information to each region's events

    content = soup.find('div', {'id': 'content'}).form.div
    if content is None:
        content = []
        regions = []
    else:
        regions = content.find_all('ul')
        
    event_hrefs = []
    for region in regions:
        events = region.find_all('li')
        for event in events:
            event_hrefs.append(EVENTS_URLS[uni] + event.a['href'])

    return event_hrefs

# %%
EVENT_ID_REGEX = re.compile(r'register\?id=([\d\w-]*)')
LATLNG_REGEX = re.compile(r'center=([^%]*)%2c([^&]*)')
TIME_RANGE_REGEX = re.compile(r'at (\d{1,2}:\d{2} \wM) until (\d{1,2}:\d{2} \wM)')

# Get event duration from a time range
def parse_duration(string):
    times = TIME_RANGE_REGEX.search(string)
    start, end = [datetime.strptime(times.group(i), '%I:%M %p') for i in [1, 2]]
    return (end - start).seconds

EVENTS = {}

# Get information from an event href
def get_event_info(href):
    
    # Check event cache to see if event has already been stored

    event_id = EVENT_ID_REGEX.search(href).group(1)
    if event_id in EVENTS:
        return EVENTS[event_id]
    else:
        print('parsing', href)
    # soup the page and find event information
    
    request = requests.get(href)
    request.raise_for_status()
    soup = BeautifulSoup(request.content)
    event = soup.find('div', {'id': 'content'}).form
    
    # Parse lat/lng of event from event map
    
    map_styles = event.find('div', {'id': 'map'})['style']
    latlng = LATLNG_REGEX.search(map_styles)
    
    # Store event in cache
    
    event_info = {
        'title': event.h1.string,
        'timestamp': event.find('input', {'id': 'form_date'})['value'],
        'duration': parse_duration(event.find('p', {'id': 'register_date'}).contents[1]),
        'venue': event.find('p', {'id': 'register_location'}).contents[0],
        'lat': float(latlng.group(1)),
        'lng': float(latlng.group(2)),
    }

    EVENTS[event_id] = event_info
    
    return event_info

# %%
# Populate EVENTS
uni = 'brown'

for f in documents[uni]:
    f = uni + '/' + f
    hrefs = get_event_hrefs(f, uni)
    print(f'=== DOCUMENT {f}, with {len(hrefs)} events')
    for href in hrefs:
        get_event_info(href)
# Out:
# === DOCUMENT brown/events_2019-05-12T10:29:01.html, with 17 events
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-7c94a53fbca9> in <module>
#       7     print(f'=== DOCUMENT {f}, with {len(hrefs)} events')
#       8     for href in hrefs:
# ----> 9         get_event_info(href)
#
# <ipython-input-94-97074280d47d> in get_event_info(href)
#      16     # Check event cache to see if event has already been stored
#      17
# ---> 18     event_id = EVENT_ID_REGEX.search(href).group(1)
#      19     if event_id in EVENTS:
#      20         return EVENTS[event_id]
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
EVENTS
# Out:
# {'3ef22548-0d01-4163-8303-a8956ff36f3c': {'title': 'EEE Evening Program in Irvine, CA',
#   'timestamp': '2019-04-29T19:00:00',
#   'duration': 7200,
#   'venue': 'Hilton Irvine/Orange County Airport',
#   'lat': 33.675,
#   'lng': -117.861},
#  '30fd0668-2d90-4373-ab12-4a1926bb0dbd': {'title': 'EEE Evening Program in San Diego, CA',
#   'timestamp': '2019-04-30T19:00:00',
#   'duration': 7200,
#   'venue': 'DoubleTree by Hilton Hotel San Diego - Mission Valley',
#   'lat': 32.77,
#   'lng': -117.16},
#  '40d3cb6f-1740-42b3-a324-224704faa8a3': {'title': 'EEE Evening Program in Berkeley, CA',
#   'timestamp': '2019-05-01T19:00:00',
#   'duration': 7200,
#   'venue': 'DoubleTree by Hilton Hotel Berkeley Marina',
#   'lat': 37.868,
#   'lng': -122.314},
#  '303bb4cf-35ae-47cf-b3f0-3f0656ec8f83': {'title': 'EEE Evening Program in San Jose, CA',
#   'timestamp': '2019-05-02T19:00:00',
#   'duration': 7200,
#   'venue': 'San Jose Marriott',
#   'lat': 37.33,
#   'lng': -121.888},
#  '0bcd2809-11ac-49b6-899d-ef0be516d202': {'title': 'EEE Evening Program in Wilmington, DE',
#   'timestamp': '2019-06-05T19:00:00',
#   'duration': 7200,
#   'venue': 'Doubletree Hotel Wilmington',
#   'lat': 39.742,
#   'lng': -75.548},
#  '4ef4a03c-e9fe-44df-8277-529962d87156': {'title': 'EEE Evening Program in Washington, D.C.',
#   'timestamp': '2019-05-21T19:00:00',
#   'duration': 7200,
#   'venue': 'Washington Marriott Wardman Park',
#   'lat': 38.925,
#   'lng': -77.054},
#  'bd01993c-a5ff-477f-8a1d-5d08dde2ae5a': {'title': 'EEE Evening Program in Orlando, FL',
#   'timestamp': '2019-04-30T19:00:00',
#   'duration': 7200,
#   'venue': 'University High School',
#   'lat': 28.578,
#   'lng': -81.216},
#  'b0840e49-ffeb-4066-8c67-4eeb60f9de57': {'title': 'EEE Evening Program in Boca Raton, FL',
#   'timestamp': '2019-05-01T19:00:00',
#   'duration': 7200,
#   'venue': 'Boca Raton Marriott',
#   'lat': 26.362,
#   'lng': -80.123},
#  'a49ac622-2544-4154-a73b-990dfca3c763': {'title': 'EEE Evening Program in Miami, FL',
#   'timestamp': '2019-05-02T19:00:00',
#   'duration': 7200,
#   'venue': 'Marriott Airport Miami',
#   'lat': 25.784,
#   'lng': -80.263},
#  '71cf1c0b-43e1-4b22-9fd0-83d573590ca1': {'title': 'EEE Afternoon Program in Chicago, IL',
#   'timestamp': '2019-06-02T14:00:00',
#   'duration': 7200,
#   'venue': 'Chicago Marriott Oak Brook',
#   'lat': 41.846,
#   'lng': -87.953},
#  '15fdef21-b664-47cb-95eb-b6ec11345989': {'title': 'EEE Evening Program in Chicago, IL',
#   'timestamp': '2019-06-02T19:00:00',
#   'duration': 7200,
#   'venue': 'Palmer House a Hilton Hotel',
#   'lat': 41.88,
#   'lng': -87.627},
#  'e33f2094-c0dd-477a-a8b9-6aefb3a13558': {'title': 'EEE Evening Program in Indianapolis, IN',
#   'timestamp': '2019-06-05T19:00:00',
#   'duration': 7200,
#   'venue': 'Sheraton Indianapolis',
#   'lat': 39.77,
#   'lng': -86.159},
#  '1f020ed7-44f9-4fc9-b711-7d6156b5d3a8': {'title': 'EEE Evening Program in Baltimore, MD',
#   'timestamp': '2019-05-19T19:00:00',
#   'duration': 7200,
#   'venue': 'Baltimore Marriott Inner Harbor at Camden Yards',
#   'lat': 39.287,
#   'lng': -76.622},
#  '09300ce1-83a0-40e9-862c-aa4317981290': {'title': 'EEE Evening Program in Gaithersburg, MD',
#   'timestamp': '2019-05-20T19:00:00',
#   'duration': 7200,
#   'venue': 'Gaithersburg Marriott Washingtonian Center',
#   'lat': 39.116,
#   'lng': -77.196},
#  'cb63f28e-73e6-418c-8f71-c16068cbe683': {'title': 'EEE Evening Program in Detroit, MI',
#   'timestamp': '2019-06-06T19:00:00',
#   'duration': 7200,
#   'venue': 'DoubleTree by Hilton Hotel Detroit - Dearborn',
#   'lat': 42.332,
#   'lng': -83.217},
#  '2aa092e3-705e-4a04-ab0a-68f81679e99b': {'title': 'EEE Evening Program in Minneapolis, MN',
#   'timestamp': '2019-06-03T19:00:00',
#   'duration': 7200,
#   'venue': 'DoubleTree by Hilton Hotel Minneapolis - Park Place',
#   'lat': 44.969,
#   'lng': -93.351},
#  'ccbaa3cf-89a2-4009-b177-b337e0157e30': {'title': 'EEE Evening Program in St. Louis, MO',
#   'timestamp': '2019-06-04T19:00:00',
#   'duration': 7200,
#   'venue': 'DoubleTree by Hilton Hotel St. Louis - Chesterfield',
#   'lat': 38.664,
#   'lng': -90.568},
#  '40b89d9d-0882-4771-b309-ab12a00afc50': {'title': 'EEE Evening Program in Plainsboro, NJ',
#   'timestamp': '2019-06-04T19:00:00',
#   'duration': 7200,
#   'venue': 'West Windsor-Plainsboro High School North',
#   'lat': 40.322,
#   'lng': -74.601},
#  'ef68d3bf-37dd-411d-80e6-a177fb4e1f9b': {'title': 'EEE Afternoon Program in New York, NY',
#   'timestamp': '2019-06-02T14:00:00',
#   'duration': 7200,
#   'venue': 'Miller Theatre',
#   'lat': 40.808,
#   'lng': -73.963},
#  'e775c18d-e9e5-40bc-8393-299e2f49dc8e': {'title': 'EEE Evening Program in White Plains, NY',
#   'timestamp': '2019-06-02T19:00:00',
#   'duration': 7200,
#   'venue': 'Crowne Plaza Hotel',
#   'lat': 41.03,
#   'lng': -73.76},
#  'af251a94-2b38-4956-8693-b93abf4e641e': {'title': 'EEE Evening Program in Dix Hills, NY',
#   'timestamp': '2019-06-03T19:00:00',
#   'duration': 7200,
#   'venue': 'Half Hollow Hills High School East',
#   'lat': 40.803,
#   'lng': -73.359},
#  '0de23f30-c3cd-43ec-a015-38f0a573b4cf': {'title': 'EEE Evening Program in King of Prussia, PA',
#   'timestamp': '2019-06-06T19:00:00',
#   'duration': 7200,
#   'venue': 'DoubleTree by Hilton Hotel Philadelphia - Valley Forge',
#   'lat': 40.091,
#   'lng': -75.37},
#  'b61f6b51-8ae2-4c3d-9b7c-12dba5948505': {'title': 'EEE Evening Program in Austin, TX',
#   'timestamp': '2019-04-30T19:00:00',
#   'duration': 7200,
#   'venue': 'Norris Conference Centers - Austin',
#   'lat': 30.357,
#   'lng': -97.735},
#  '346ca5c0-d44f-4a02-a786-70b752269194': {'title': 'EEE Evening Program in Dallas, TX',
#   'timestamp': '2019-05-01T19:00:00',
#   'duration': 7200,
#   'venue': 'Irving Convention Center at Las Colinas',
#   'lat': 32.878,
#   'lng': -96.943},
#  '798060c4-d8c3-4651-b4be-8ad65339bd3f': {'title': 'EEE Evening Program in Fort Worth, TX',
#   'timestamp': '2019-05-02T19:00:00',
#   'duration': 7200,
#   'venue': 'Sheraton Fort Worth Downtown Hotel',
#   'lat': 32.748,
#   'lng': -97.325},
#  'fa5ce5f4-4657-4c10-8628-eb6fda662611': {'title': 'EEE Evening Program in Alexandria, VA',
#   'timestamp': '2019-05-22T19:00:00',
#   'duration': 7200,
#   'venue': 'Tysons Corner Marriott',
#   'lat': 38.913,
#   'lng': -77.223},
#  'c52eb675-7aef-4a20-87f5-6c4823e0ab62': {'title': 'EEE Evening Program in Richmond, VA',
#   'timestamp': '2019-05-23T19:00:00',
#   'duration': 7200,
#   'venue': 'Delta Hotels by Marriott Richmond Downtown',
#   'lat': 37.538,
#   'lng': -77.441},
#  '33440e33-a2ca-4004-a444-f96d5231922f': {'title': 'Introduction to Columbia: Chicago',
#   'timestamp': '2019-07-11T18:00:00',
#   'duration': 7200,
#   'venue': 'Whitney M Young Magnet High School',
#   'lat': 41.878,
#   'lng': -87.664}}

# %%
EVENTS_LIST = []

for key in EVENTS.keys():
    event = EVENTS[key]
    event['id'] = key
    EVENTS_LIST.append(event)

# %%
with open('../data/events.json', 'w') as f:
    f.write(json.dumps(EVENTS_LIST))
