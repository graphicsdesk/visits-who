# %% [markdown]
# ## Guiding questions
#
# Where does Columbia Visits You visit?

# %%
from bs4 import BeautifulSoup, NavigableString
from datetime import datetime

import os
import requests
import re
import json

# %%
# DUPLICATE OF THE VERSION IN SCRAPER

EVENTS_URLS = {
    'brown': 'https://apply.college.brown.edu/portal/brown-near-you',
    'columbia': 'https://apply.college.columbia.edu/portal/register',
    'mit': 'https://mitadmissions.org/visit/mit-visits-you/fall-travel',
    'princeton': 'https://apply.princeton.edu/portal/upcoming_events',
    'stanford': 'https://apply.stanford.edu/portal/stanfordinyourarea',
    'uchicago': 'https://prospects.uchicago.edu/register/?c=&country=',
    'upenn': 'https://key.admissions.upenn.edu/portal/penn-in-your-town?c=&country=',
    'yale': 'https://apps.admissions.yale.edu/portal/events',    
    'eco': 'http://www.exploringcollegeoptions.org',
}

# %%
documents = {}

for directory in os.listdir('../documents'):
    if directory == '.DS_Store':
        continue
    documents[directory] = sorted(
        [f for f in os.listdir('../documents/' + directory) if 'events_' in f]
    )

# %%
# Returns event hrefs from a document
def get_event_hrefs(fname, uni):
    # soup file contents
    html = open('../documents/' + fname, 'r').read()
    soup = BeautifulSoup(html)
    
    # Find and store information to each region's events
    if uni == 'uchicago':
        content = soup.find('div', {'class': 'content2'})
    elif uni == 'mit':
        content = soup.find('div', {'id': 'page-text-mod'})
        rsvps = [
            a['href'] for a in content.findAll('a')
            if a.text == 'RSVP'
        ]
        return [
            r for r in rsvps
            if r != 'https://mitadmissions.org/rsvp-az/'
        ]
    else:
        content = soup.find('div', {'id': 'content'})
    content = content.form.div
    if content is None:
        content = []
        regions = []
    else:
        regions = content.find_all('ul')
        
    event_hrefs = []
    for region in regions:
        events = region.find_all('li')
        for event in events:
            event_hrefs.append(EVENTS_URLS[uni].split('?')[0] + event.a['href'])

    return event_hrefs

# %%
EVENT_ID_REGEX = re.compile(r'\?id=([\d\w-]*)')
LATLNG_REGEX = re.compile(r'center=([^%]*)%2c([^&]*)')
TIME_RANGE_REGEX = re.compile(r'at (\d{1,2}:\d{2} \wM)( until (\d{1,2}:\d{2} \wM))?')

# Get event duration from a time range
def parse_duration(string):
    times = TIME_RANGE_REGEX.findall(string)[0]
    if len(times[1]) == 0 and len(times[2]) == 0:
        return None
    start, end = [datetime.strptime(times[i], '%I:%M %p') for i in [0, 2]]
    return (end - start).seconds

EVENTS = {}

# Get information from an event href
def get_event_info(href):    
    # Check event cache to see if event has already been stored
    event_id = EVENT_ID_REGEX.search(href)
    if event_id is None:
        if href.find('https://apps.admissions.yale.edu/register/') == 0:
            event_id = href.split('/')[-1]
    else:
        event_id = event_id.group(1)
    if event_id in EVENTS:
        return EVENTS[event_id]
    else:
        print('parsing', href)
    # soup the page and find event information
    
    request = requests.get(href)
    request.raise_for_status()
    soup = BeautifulSoup(request.content)

    event = soup.find('div', {'id': 'content'})
    if event is None: # uchicago
        event = soup.find('div', {'class': 'content2'})
        title = soup.find('h1', {'class': 'title'})
    event = event.form
    
    event_info = {
        'title': (event.h1 or title).string,
        'timestamp': event.find('input', {'id': 'form_date'})['value'],
        'duration': parse_duration(event.find('p', {'id': 'register_date'}).contents[1]),
        'venue': event.find('p', {'id': 'register_location'}).contents[0],
    }
    
    # Parse location of event from event map
    map_div = event.find('div', {'id': 'map'})
    if map_div is None:
        event_info['address'] = '\n'.join([
            x for x in list(event.find('p', {'id': 'register_location'}).children)
            if type(x) == NavigableString
        ])
    else:
        map_styles = event.find('div', {'id': 'map'})['style']
        latlng = LATLNG_REGEX.search(map_styles)
        event_info['lat'] = float(latlng.group(1))
        event_info['lng'] = float(latlng.group(2))

    EVENTS[event_id] = event_info
    
    return event_info

# %%
# Populate EVENTS
for uni in EVENTS_URLS.keys():
    if uni == 'eco':
        continue
    print(f'***** {uni} *****')
    for f in documents[uni]:
        f = uni + '/' + f
        hrefs = get_event_hrefs(f, uni)
        print(f'=== DOCUMENT {f}, with {len(hrefs)} events')
        for href in hrefs:
            get_event_info(href)
# Out:
# ***** brown *****
# === DOCUMENT brown/events_2019-05-12T10:29:01.html, with 17 events
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=7eecdbcc-8b39-47cb-b95c-fa6723bf2b70
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=1a45ac57-b6f9-4b27-8c77-8c1d758f8bad
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=043ad2a6-870e-4d0a-9ad5-0aace683644c
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=26beb80e-d2f6-4848-8006-980ea35034e3
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=f62f987d-15a6-424d-8a2e-424ae4a51fd9
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=320675e9-88c1-4036-b9eb-32624e1d2fad
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=edada695-dd94-4cf2-afcf-63d9a5daa70a
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=2c96a53b-26fc-4e4a-8247-9c54855cc4ae
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=81d48a5b-b85b-474b-92de-bf6bbc5e6532
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=3e398dff-485c-4318-a685-fe3e89bf9993
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=2d5c87b8-72a5-4efc-b921-cd25f289ad0d
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=0e651d01-00e1-493a-a126-1969fe82443c
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=b6709e48-96a0-45f8-b37a-115555c7a63c
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=5e97e96e-cee4-4f44-9ce0-99cfd3d4c798
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=843f2f77-ae18-4195-9c26-6603f1d51ae9
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=da7cec19-ce2b-45dd-bb9a-bb85cf8262bb
# parsing https://apply.college.brown.edu/portal/brown-near-you?id=00c2b23a-57c9-425f-8274-3f19e5394dce
# === DOCUMENT brown/events_2019-05-13T10:00:01.html, with 17 events
# === DOCUMENT brown/events_2019-05-14T10:00:01.html, with 17 events
# === DOCUMENT brown/events_2019-05-15T11:01:45.html, with 17 events
# === DOCUMENT brown/events_2019-05-17T11:00:01.html, with 17 events
# === DOCUMENT brown/events_2019-05-18T11:00:01.html, with 17 events
# === DOCUMENT brown/events_2019-05-19T12:00:01.html, with 17 events
# === DOCUMENT brown/events_2019-05-20T10:00:01.html, with 16 events
# === DOCUMENT brown/events_2019-05-21T03:00:01.html, with 15 events
# === DOCUMENT brown/events_2019-05-22T10:00:01.html, with 14 events
# === DOCUMENT brown/events_2019-05-23T10:00:01.html, with 13 events
# === DOCUMENT brown/events_2019-05-24T09:00:01.html, with 12 events
# === DOCUMENT brown/events_2019-05-25T08:00:02.html, with 12 events
# === DOCUMENT brown/events_2019-05-26T10:00:02.html, with 12 events
# === DOCUMENT brown/events_2019-05-27T00:00:00.html, with 12 events
# === DOCUMENT brown/events_2019-05-28T00:00:00.html, with 12 events
# === DOCUMENT brown/events_2019-05-29T03:00:02.html, with 12 events
# === DOCUMENT brown/events_2019-05-30T00:00:01.html, with 12 events
# === DOCUMENT brown/events_2019-05-31T05:00:00.html, with 12 events
# === DOCUMENT brown/events_2019-06-01T11:00:01.html, with 12 events
# === DOCUMENT brown/events_2019-06-02T09:00:01.html, with 12 events
# === DOCUMENT brown/events_2019-06-03T00:00:01.html, with 8 events
# === DOCUMENT brown/events_2019-06-04T00:00:02.html, with 6 events
# === DOCUMENT brown/events_2019-06-05T09:00:01.html, with 4 events
# === DOCUMENT brown/events_2019-06-06T09:00:01.html, with 2 events
# === DOCUMENT brown/events_2019-06-07T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-08T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-09T08:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-10T09:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-11T09:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-12T09:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-13T09:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-14T02:00:02.html, with 0 events
# === DOCUMENT brown/events_2019-06-15T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-16T10:00:05.html, with 0 events
# === DOCUMENT brown/events_2019-06-17T22:00:02.html, with 0 events
# === DOCUMENT brown/events_2019-06-18T08:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-19T00:00:02.html, with 0 events
# === DOCUMENT brown/events_2019-06-20T09:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-21T00:00:02.html, with 0 events
# === DOCUMENT brown/events_2019-06-22T10:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-23T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-24T09:01:38.html, with 0 events
# === DOCUMENT brown/events_2019-06-25T01:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-26T00:00:00.html, with 0 events
# === DOCUMENT brown/events_2019-06-28T12:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-29T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-06-30T14:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-01T22:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-02T08:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-03T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-07T10:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-09T23:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-10T08:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-11T08:00:02.html, with 0 events
# === DOCUMENT brown/events_2019-07-12T23:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-13T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-14T00:00:02.html, with 0 events
# === DOCUMENT brown/events_2019-07-15T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-16T00:00:00.html, with 0 events
# === DOCUMENT brown/events_2019-07-17T00:00:01.html, with 0 events
# === DOCUMENT brown/events_2019-07-18T00:00:00.html, with 0 events
# === DOCUMENT brown/events_2019-07-19T20:00:01.html, with 0 events
# ***** columbia *****
# === DOCUMENT columbia/events_2019-04-29T21:42:53.html, with 27 events
# parsing https://apply.college.columbia.edu/portal/register?id=3ef22548-0d01-4163-8303-a8956ff36f3c
# parsing https://apply.college.columbia.edu/portal/register?id=30fd0668-2d90-4373-ab12-4a1926bb0dbd
# parsing https://apply.college.columbia.edu/portal/register?id=40d3cb6f-1740-42b3-a324-224704faa8a3
# parsing https://apply.college.columbia.edu/portal/register?id=303bb4cf-35ae-47cf-b3f0-3f0656ec8f83
# parsing https://apply.college.columbia.edu/portal/register?id=0bcd2809-11ac-49b6-899d-ef0be516d202
# parsing https://apply.college.columbia.edu/portal/register?id=4ef4a03c-e9fe-44df-8277-529962d87156
# parsing https://apply.college.columbia.edu/portal/register?id=bd01993c-a5ff-477f-8a1d-5d08dde2ae5a
# parsing https://apply.college.columbia.edu/portal/register?id=b0840e49-ffeb-4066-8c67-4eeb60f9de57
# parsing https://apply.college.columbia.edu/portal/register?id=a49ac622-2544-4154-a73b-990dfca3c763
# parsing https://apply.college.columbia.edu/portal/register?id=71cf1c0b-43e1-4b22-9fd0-83d573590ca1
# parsing https://apply.college.columbia.edu/portal/register?id=15fdef21-b664-47cb-95eb-b6ec11345989
# parsing https://apply.college.columbia.edu/portal/register?id=e33f2094-c0dd-477a-a8b9-6aefb3a13558
# parsing https://apply.college.columbia.edu/portal/register?id=1f020ed7-44f9-4fc9-b711-7d6156b5d3a8
# parsing https://apply.college.columbia.edu/portal/register?id=09300ce1-83a0-40e9-862c-aa4317981290
# parsing https://apply.college.columbia.edu/portal/register?id=cb63f28e-73e6-418c-8f71-c16068cbe683
# parsing https://apply.college.columbia.edu/portal/register?id=2aa092e3-705e-4a04-ab0a-68f81679e99b
# parsing https://apply.college.columbia.edu/portal/register?id=ccbaa3cf-89a2-4009-b177-b337e0157e30
# parsing https://apply.college.columbia.edu/portal/register?id=40b89d9d-0882-4771-b309-ab12a00afc50
# parsing https://apply.college.columbia.edu/portal/register?id=ef68d3bf-37dd-411d-80e6-a177fb4e1f9b
# parsing https://apply.college.columbia.edu/portal/register?id=e775c18d-e9e5-40bc-8393-299e2f49dc8e
# parsing https://apply.college.columbia.edu/portal/register?id=af251a94-2b38-4956-8693-b93abf4e641e
# parsing https://apply.college.columbia.edu/portal/register?id=0de23f30-c3cd-43ec-a015-38f0a573b4cf
# parsing https://apply.college.columbia.edu/portal/register?id=b61f6b51-8ae2-4c3d-9b7c-12dba5948505
# parsing https://apply.college.columbia.edu/portal/register?id=346ca5c0-d44f-4a02-a786-70b752269194
# parsing https://apply.college.columbia.edu/portal/register?id=798060c4-d8c3-4651-b4be-8ad65339bd3f
# parsing https://apply.college.columbia.edu/portal/register?id=fa5ce5f4-4657-4c10-8628-eb6fda662611
# parsing https://apply.college.columbia.edu/portal/register?id=c52eb675-7aef-4a20-87f5-6c4823e0ab62
# === DOCUMENT columbia/events_2019-04-30T10:39:28.html, with 26 events
# === DOCUMENT columbia/events_2019-05-02T17:02:08.html, with 20 events
# === DOCUMENT columbia/events_2019-05-04T14:43:02.html, with 17 events
# === DOCUMENT columbia/events_2019-05-06T10:54:59.html, with 17 events
# === DOCUMENT columbia/events_2019-05-07T10:25:50.html, with 17 events
# === DOCUMENT columbia/events_2019-05-07T11:08:36.html, with 17 events
# === DOCUMENT columbia/events_2019-05-09T12:00:47.html, with 17 events
# === DOCUMENT columbia/events_2019-05-09T20:43:54.html, with 17 events
# === DOCUMENT columbia/events_2019-05-10T12:04:35.html, with 17 events
# === DOCUMENT columbia/events_2019-05-11T01:23:54.html, with 17 events
# === DOCUMENT columbia/events_2019-05-12T09:25:38.html, with 17 events
# === DOCUMENT columbia/events_2019-05-12T09:52:41.html, with 17 events
# === DOCUMENT columbia/events_2019-05-12T10:00:00.html, with 17 events
# === DOCUMENT columbia/events_2019-05-12T10:24:36.html, with 17 events
# === DOCUMENT columbia/events_2019-05-12T10:29:01.html, with 17 events
# === DOCUMENT columbia/events_2019-05-13T10:00:01.html, with 17 events
# === DOCUMENT columbia/events_2019-05-14T10:00:01.html, with 17 events
# === DOCUMENT columbia/events_2019-05-15T11:01:45.html, with 17 events
# === DOCUMENT columbia/events_2019-05-17T11:00:02.html, with 17 events
# === DOCUMENT columbia/events_2019-05-18T11:00:01.html, with 17 events
# === DOCUMENT columbia/events_2019-05-19T12:00:01.html, with 17 events
# === DOCUMENT columbia/events_2019-05-20T10:00:01.html, with 16 events
# === DOCUMENT columbia/events_2019-05-21T03:00:01.html, with 15 events
# === DOCUMENT columbia/events_2019-05-22T10:00:02.html, with 14 events
# === DOCUMENT columbia/events_2019-05-23T10:00:02.html, with 13 events
# === DOCUMENT columbia/events_2019-05-24T09:00:02.html, with 12 events
# === DOCUMENT columbia/events_2019-05-25T08:00:05.html, with 12 events
# === DOCUMENT columbia/events_2019-05-26T10:00:02.html, with 12 events
# === DOCUMENT columbia/events_2019-05-27T00:00:01.html, with 12 events
# === DOCUMENT columbia/events_2019-05-28T00:00:01.html, with 12 events
# === DOCUMENT columbia/events_2019-05-29T03:00:03.html, with 12 events
# === DOCUMENT columbia/events_2019-05-30T00:00:02.html, with 12 events
# === DOCUMENT columbia/events_2019-05-31T05:00:01.html, with 12 events
# === DOCUMENT columbia/events_2019-06-01T11:00:01.html, with 12 events
# === DOCUMENT columbia/events_2019-06-02T09:00:02.html, with 12 events
# === DOCUMENT columbia/events_2019-06-03T00:00:01.html, with 8 events
# === DOCUMENT columbia/events_2019-06-04T00:00:02.html, with 6 events
# === DOCUMENT columbia/events_2019-06-05T09:00:01.html, with 4 events
# === DOCUMENT columbia/events_2019-06-06T09:00:02.html, with 2 events
# === DOCUMENT columbia/events_2019-06-07T00:00:05.html, with 0 events
# === DOCUMENT columbia/events_2019-06-08T00:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-09T08:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-10T09:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-06-11T09:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-12T09:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-06-13T09:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-06-14T02:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-15T00:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-06-16T10:00:06.html, with 0 events
# === DOCUMENT columbia/events_2019-06-17T22:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-18T08:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-06-19T00:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-20T09:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-21T00:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-22T10:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-06-23T00:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-06-24T09:01:39.html, with 0 events
# === DOCUMENT columbia/events_2019-06-25T01:00:02.html, with 1 events
# parsing https://apply.college.columbia.edu/portal/register?id=33440e33-a2ca-4004-a444-f96d5231922f
# === DOCUMENT columbia/events_2019-06-26T00:00:02.html, with 1 events
# === DOCUMENT columbia/events_2019-06-28T12:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-06-29T00:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-06-30T14:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-07-01T22:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-07-02T08:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-07-03T00:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-07-07T10:00:02.html, with 1 events
# === DOCUMENT columbia/events_2019-07-09T23:00:01.html, with 1 events
# === DOCUMENT columbia/events_2019-07-10T08:00:02.html, with 1 events
# === DOCUMENT columbia/events_2019-07-11T08:00:03.html, with 1 events
# === DOCUMENT columbia/events_2019-07-12T23:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-07-13T00:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-07-14T00:00:04.html, with 0 events
# === DOCUMENT columbia/events_2019-07-15T00:00:02.html, with 0 events
# === DOCUMENT columbia/events_2019-07-16T00:00:00.html, with 0 events
# === DOCUMENT columbia/events_2019-07-17T00:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-07-18T00:00:01.html, with 0 events
# === DOCUMENT columbia/events_2019-07-19T20:00:01.html, with 0 events
# ***** mit *****
# === DOCUMENT mit/events_2019-05-12T10:33:22.html, with 5 events
# parsing https://apps.admissions.yale.edu/register/CMPYMcAllen2019
# parsing https://apps.admissions.yale.edu/register/CMPYNewOrleans2019
# parsing https://apps.admissions.yale.edu/register/CMPYPensacola2019
# parsing https://apps.admissions.yale.edu/register/CMPYJacksonville2019
# parsing https://apps.admissions.yale.edu/register/CMPYOrlando2019
# === DOCUMENT mit/events_2019-05-13T10:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-05-14T10:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-15T11:01:46.html, with 5 events
# === DOCUMENT mit/events_2019-05-17T11:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-05-18T11:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-19T12:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-20T10:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-21T03:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-22T10:00:04.html, with 5 events
# === DOCUMENT mit/events_2019-05-23T10:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-24T09:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-25T08:00:06.html, with 5 events
# === DOCUMENT mit/events_2019-05-26T10:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-27T00:00:01.html, with 5 events
# === DOCUMENT mit/events_2019-05-28T00:00:01.html, with 5 events
# === DOCUMENT mit/events_2019-05-29T03:00:07.html, with 5 events
# === DOCUMENT mit/events_2019-05-30T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-05-31T05:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-01T11:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-02T09:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-03T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-04T00:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-05T09:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-06T09:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-07T00:00:05.html, with 5 events
# === DOCUMENT mit/events_2019-06-08T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-09T08:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-10T09:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-11T09:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-12T09:00:04.html, with 5 events
# === DOCUMENT mit/events_2019-06-13T09:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-14T02:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-15T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-16T10:00:07.html, with 5 events
# === DOCUMENT mit/events_2019-06-17T22:00:04.html, with 5 events
# === DOCUMENT mit/events_2019-06-18T08:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-19T00:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-20T09:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-21T00:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-22T10:00:01.html, with 5 events
# === DOCUMENT mit/events_2019-06-23T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-24T09:01:41.html, with 5 events
# === DOCUMENT mit/events_2019-06-25T01:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-26T00:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-06-28T12:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-29T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-06-30T14:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-07-01T22:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-07-02T08:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-07-03T00:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-07-07T10:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-07-09T23:00:01.html, with 5 events
# === DOCUMENT mit/events_2019-07-10T08:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-07-11T08:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-07-12T23:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-07-13T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-07-14T00:00:05.html, with 5 events
# === DOCUMENT mit/events_2019-07-15T00:00:03.html, with 5 events
# === DOCUMENT mit/events_2019-07-16T00:00:01.html, with 5 events
# === DOCUMENT mit/events_2019-07-17T00:00:02.html, with 5 events
# === DOCUMENT mit/events_2019-07-18T00:00:01.html, with 5 events
# === DOCUMENT mit/events_2019-07-19T20:00:02.html, with 5 events
# ***** princeton *****
# === DOCUMENT princeton/events_2019-05-12T10:29:02.html, with 20 events
# parsing https://apply.princeton.edu/portal/upcoming_events?id=33ead71c-7167-416b-a328-e47d515b6a68
# parsing https://apply.princeton.edu/portal/upcoming_events?id=a4b5d27d-9f64-411b-8397-ada936fe670b
# parsing https://apply.princeton.edu/portal/upcoming_events?id=41de5e21-d6ea-4e58-b9a6-07131a3a8edd
# parsing https://apply.princeton.edu/portal/upcoming_events?id=9863a21f-6340-4cf2-a631-0ca5fac99d24
# parsing https://apply.princeton.edu/portal/upcoming_events?id=14ce253f-1c36-40fc-8ade-fd3932f6260b
# parsing https://apply.princeton.edu/portal/upcoming_events?id=c9d091e8-8b97-40e0-8b32-95c5a78912d9
# parsing https://apply.princeton.edu/portal/upcoming_events?id=7db8d3d1-6958-41a5-862e-3a446a049e77
# parsing https://apply.princeton.edu/portal/upcoming_events?id=4770d6b4-4510-4e0a-9623-bef3208879f9
# parsing https://apply.princeton.edu/portal/upcoming_events?id=e586c281-a851-47ab-893f-40d192536fd3
# parsing https://apply.princeton.edu/portal/upcoming_events?id=eca35c67-3874-4471-a11a-9558da4dce62
# parsing https://apply.princeton.edu/portal/upcoming_events?id=d9ee406d-4001-4f6c-bff7-4cae8923134b
# parsing https://apply.princeton.edu/portal/upcoming_events?id=7d986b10-4973-4e72-976a-1a4bae1c30b2
# parsing https://apply.princeton.edu/portal/upcoming_events?id=d865ae85-b725-4509-be4a-98f7e775a07f
# parsing https://apply.princeton.edu/portal/upcoming_events?id=4856aeee-0d80-4bf2-8feb-ebf13308de23
# parsing https://apply.princeton.edu/portal/upcoming_events?id=658c0fca-5695-4e86-9b23-3c3be4dc9786
# parsing https://apply.princeton.edu/portal/upcoming_events?id=a26a80d5-9a73-4b3b-bbf8-74ebdc88df2c
# parsing https://apply.princeton.edu/portal/upcoming_events?id=2cdc21e0-f0a6-4f41-ba2a-4272917b1605
# parsing https://apply.princeton.edu/portal/upcoming_events?id=70d3195e-dd9d-446c-b1e1-30e0755417cd
# parsing https://apply.princeton.edu/portal/upcoming_events?id=ba94e130-8e49-48ca-bd22-fd536e112e1d
# parsing https://apply.princeton.edu/portal/upcoming_events?id=155dd216-5806-4190-ab3f-bb7af6b75c26
# === DOCUMENT princeton/events_2019-05-13T10:00:03.html, with 20 events
# === DOCUMENT princeton/events_2019-05-14T10:00:03.html, with 20 events
# === DOCUMENT princeton/events_2019-05-15T11:01:46.html, with 20 events
# === DOCUMENT princeton/events_2019-05-17T11:00:03.html, with 20 events
# === DOCUMENT princeton/events_2019-05-18T11:00:02.html, with 20 events
# === DOCUMENT princeton/events_2019-05-19T12:00:03.html, with 19 events
# === DOCUMENT princeton/events_2019-05-20T10:00:03.html, with 17 events
# === DOCUMENT princeton/events_2019-05-21T03:00:02.html, with 15 events
# === DOCUMENT princeton/events_2019-05-22T10:00:05.html, with 13 events
# === DOCUMENT princeton/events_2019-05-23T10:00:03.html, with 11 events
# === DOCUMENT princeton/events_2019-05-24T09:00:02.html, with 9 events
# === DOCUMENT princeton/events_2019-05-25T08:00:06.html, with 9 events
# === DOCUMENT princeton/events_2019-05-26T10:00:03.html, with 9 events
# === DOCUMENT princeton/events_2019-05-27T00:00:02.html, with 9 events
# === DOCUMENT princeton/events_2019-05-28T00:00:02.html, with 9 events
# === DOCUMENT princeton/events_2019-05-29T03:00:07.html, with 9 events
# === DOCUMENT princeton/events_2019-05-30T00:00:03.html, with 9 events
# === DOCUMENT princeton/events_2019-05-31T05:00:02.html, with 9 events
# === DOCUMENT princeton/events_2019-06-01T11:00:03.html, with 8 events
# parsing https://apply.stanford.edu/portal/stanfordinyourarea?id=04911009-f80b-4419-b329-bef9a580cc6f
# parsing https://apply.stanford.edu/portal/stanfordinyourarea?id=eec39066-f213-4c43-9027-22fb35bf2725
# === DOCUMENT stanford/events_2019-05-13T10:00:03.html, with 64 events
# === DOCUMENT stanford/events_2019-05-14T10:00:03.html, with 57 events
# === DOCUMENT stanford/events_2019-05-15T11:01:47.html, with 50 events
# === DOCUMENT stanford/events_2019-05-17T11:00:03.html, with 36 events
# === DOCUMENT stanford/events_2019-05-18T11:00:02.html, with 36 events
# === DOCUMENT stanford/events_2019-05-19T12:00:03.html, with 36 events
# === DOCUMENT stanford/events_2019-05-20T10:00:03.html, with 29 events
# === DOCUMENT stanford/events_2019-05-21T03:00:02.html, with 22 events
# === DOCUMENT stanford/events_2019-05-22T10:00:06.html, with 15 events
# === DOCUMENT stanford/events_2019-05-23T10:00:03.html, with 8 events
# === DOCUMENT stanford/events_2019-05-24T09:00:03.html, with 1 events
# === DOCUMENT stanford/events_2019-05-25T08:00:06.html, with 1 events
# === DOCUMENT stanford/events_2019-05-26T10:00:03.html, with 1 events
# === DOCUMENT stanford/events_2019-05-27T00:00:02.html, with 1 events
# === DOCUMENT stanford/events_2019-05-28T00:00:02.html, with 1 events
# === DOCUMENT stanford/events_2019-05-29T03:00:07.html, with 1 events
# === DOCUMENT stanford/events_2019-05-30T00:00:03.html, with 1 events
# === DOCUMENT stanford/events_2019-05-31T05:00:02.html, with 1 events
# === DOCUMENT stanford/events_2019-06-01T11:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-02T09:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-03T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-04T00:00:04.html, with 0 events
# === DOCUMENT stanford/events_2019-06-05T09:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-06T09:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-07T00:00:06.html, with 0 events
# === DOCUMENT stanford/events_2019-06-08T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-09T08:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-10T09:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-11T09:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-12T09:00:05.html, with 0 events
# === DOCUMENT stanford/events_2019-06-13T09:00:04.html, with 0 events
# === DOCUMENT stanford/events_2019-06-14T02:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-15T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-16T10:00:07.html, with 0 events
# === DOCUMENT stanford/events_2019-06-17T22:00:05.html, with 0 events
# === DOCUMENT stanford/events_2019-06-18T08:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-19T00:00:04.html, with 0 events
# === DOCUMENT stanford/events_2019-06-20T09:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-21T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-22T10:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-06-23T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-24T09:01:42.html, with 0 events
# === DOCUMENT stanford/events_2019-06-25T01:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-26T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-06-28T12:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-06-29T00:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-06-30T14:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-07-01T22:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-07-02T08:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-07-03T00:00:05.html, with 0 events
# === DOCUMENT stanford/events_2019-07-07T10:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-07-09T23:00:11.html, with 0 events
# === DOCUMENT stanford/events_2019-07-10T08:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-07-11T08:00:04.html, with 0 events
# === DOCUMENT stanford/events_2019-07-12T23:00:04.html, with 0 events
# === DOCUMENT stanford/events_2019-07-13T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-07-14T00:00:05.html, with 0 events
# === DOCUMENT stanford/events_2019-07-15T00:00:04.html, with 0 events
# === DOCUMENT stanford/events_2019-07-16T00:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-07-17T00:00:03.html, with 0 events
# === DOCUMENT stanford/events_2019-07-18T00:00:02.html, with 0 events
# === DOCUMENT stanford/events_2019-07-19T20:00:03.html, with 0 events
# ***** uchicago *****
# === DOCUMENT uchicago/events_2019-05-12T10:29:02.html, with 18 events
# parsing https://prospects.uchicago.edu/register/?id=8125279a-931c-4265-aa94-ffea0b136d2e
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=d9976847-2a4b-4198-a99f-653d9b790726
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=12a21786-fd8f-4424-996b-f4e4d0684103
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=59a72973-c4bc-4127-ad68-48450e026c48
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=463af2ba-e343-42ca-bf1d-e11ded84f277
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=327a43a5-379e-4624-bf86-28889c2670e6
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=a1e890ec-5791-439e-8f43-df870b7578d3
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=4e33014b-0123-4704-a56b-f4bb97057db6
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=9e946c19-a5ed-4f6d-977e-adf33a51c388
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=2e0a7ca2-a731-4374-817d-9430a175cdc0
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=415cfec9-1a1c-4eaa-8ea1-64d46dcc040d
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=7b578cf0-047a-45f4-a942-94c1dc246b5e
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=a5b60e8d-344f-4df4-980a-9c68fd16618d
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=a1cf2cc9-cd1d-4a33-9276-8b9a54575f8b
# === DOCUMENT upenn/events_2019-05-13T10:00:04.html, with 64 events
# === DOCUMENT upenn/events_2019-05-14T10:00:04.html, with 57 events
# === DOCUMENT upenn/events_2019-05-15T11:01:47.html, with 50 events
# === DOCUMENT upenn/events_2019-05-17T11:00:04.html, with 36 events
# === DOCUMENT upenn/events_2019-05-18T11:00:03.html, with 36 events
# === DOCUMENT upenn/events_2019-05-19T12:00:04.html, with 36 events
# === DOCUMENT upenn/events_2019-05-20T10:00:04.html, with 29 events
# === DOCUMENT upenn/events_2019-05-21T03:00:03.html, with 22 events
# === DOCUMENT upenn/events_2019-05-22T10:00:07.html, with 15 events
# === DOCUMENT upenn/events_2019-05-23T10:00:04.html, with 8 events
# === DOCUMENT upenn/events_2019-05-24T09:00:04.html, with 1 events
# === DOCUMENT upenn/events_2019-05-25T08:00:07.html, with 1 events
# === DOCUMENT upenn/events_2019-05-26T10:00:03.html, with 1 events
# === DOCUMENT upenn/events_2019-05-27T00:00:03.html, with 1 events
# === DOCUMENT upenn/events_2019-05-28T00:00:03.html, with 1 events
# === DOCUMENT upenn/events_2019-05-29T03:00:08.html, with 1 events
# === DOCUMENT upenn/events_2019-05-30T00:00:07.html, with 1 events
# === DOCUMENT upenn/events_2019-05-31T05:00:03.html, with 1 events
# === DOCUMENT upenn/events_2019-06-01T11:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-02T09:00:03.html, with 0 events
# === DOCUMENT upenn/events_2019-06-03T00:00:03.html, with 0 events
# === DOCUMENT upenn/events_2019-06-04T00:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-05T09:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-06T09:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-07T00:00:07.html, with 0 events
# === DOCUMENT upenn/events_2019-06-08T00:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-09T08:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-10T09:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-11T09:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-12T09:00:06.html, with 0 events
# === DOCUMENT upenn/events_2019-06-13T09:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-14T02:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-15T00:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-16T10:00:08.html, with 0 events
# === DOCUMENT upenn/events_2019-06-17T22:00:08.html, with 0 events
# === DOCUMENT upenn/events_2019-06-18T08:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-19T00:00:05.html, with 0 events
# === DOCUMENT upenn/events_2019-06-20T09:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-21T00:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-22T10:00:02.html, with 0 events
# === DOCUMENT upenn/events_2019-06-23T00:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-24T09:01:43.html, with 0 events
# === DOCUMENT upenn/events_2019-06-25T01:00:03.html, with 0 events
# === DOCUMENT upenn/events_2019-06-26T00:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-06-28T12:00:03.html, with 0 events
# === DOCUMENT upenn/events_2019-06-29T00:00:03.html, with 0 events
# === DOCUMENT upenn/events_2019-06-30T14:00:03.html, with 0 events
# === DOCUMENT upenn/events_2019-07-01T22:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-07-02T08:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-07-03T00:00:05.html, with 0 events
# === DOCUMENT upenn/events_2019-07-07T10:00:04.html, with 0 events
# === DOCUMENT upenn/events_2019-07-09T23:00:12.html, with 1 events
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=41deacbe-6f5e-44e3-ae7e-9e0813d6d720
# === DOCUMENT upenn/events_2019-07-10T08:00:04.html, with 1 events
# === DOCUMENT upenn/events_2019-07-11T08:00:06.html, with 1 events
# === DOCUMENT upenn/events_2019-07-12T23:00:04.html, with 1 events
# === DOCUMENT upenn/events_2019-07-13T00:00:04.html, with 1 events
# === DOCUMENT upenn/events_2019-07-14T00:00:06.html, with 1 events
# === DOCUMENT upenn/events_2019-07-15T00:00:05.html, with 1 events
# === DOCUMENT upenn/events_2019-07-16T00:00:03.html, with 1 events
# === DOCUMENT upenn/events_2019-07-17T00:00:03.html, with 5 events
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=c300054e-64b9-4208-ac1b-bf4d491f2b10
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=a8d95db7-fc60-430d-99e3-ab69ceadf2f0
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=0049f578-0fda-4bfd-aab8-ddc63b1861bb
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=dacd8096-07c6-407b-a3d6-b524525ee1c1
# === DOCUMENT upenn/events_2019-07-18T00:00:03.html, with 5 events
# === DOCUMENT upenn/events_2019-07-19T20:00:03.html, with 6 events
# parsing https://key.admissions.upenn.edu/portal/penn-in-your-town?id=e827d78a-0b12-4665-91c8-5f57bb82b3f7
# ***** yale *****
# === DOCUMENT yale/events_2019-05-12T10:29:02.html, with 4 events
# parsing https://apps.admissions.yale.edu/portal/events?id=a370eae8-e02a-49fb-ba0a-fe4493093c34
# parsing https://apps.admissions.yale.edu/portal/events?id=9238361c-1681-4bca-93c7-1d2840964780
# parsing https://apps.admissions.yale.edu/portal/events?id=2d7b4f80-5e39-4481-9022-d951bdcc4103
# parsing https://apps.admissions.yale.edu/portal/events?id=d6aa3f38-7a87-4a8d-a802-0f8402949af4
# === DOCUMENT yale/events_2019-05-13T10:00:04.html, with 4 events
# === DOCUMENT yale/events_2019-05-14T10:00:04.html, with 5 events
# parsing https://apps.admissions.yale.edu/portal/events?id=e8be32a0-ba5f-472a-9c00-52f57db78821
# === DOCUMENT yale/events_2019-05-15T11:01:48.html, with 5 events
# === DOCUMENT yale/events_2019-05-17T11:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-18T11:00:03.html, with 5 events
# === DOCUMENT yale/events_2019-05-19T12:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-20T10:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-21T03:00:03.html, with 5 events
# === DOCUMENT yale/events_2019-05-22T10:00:07.html, with 5 events
# === DOCUMENT yale/events_2019-05-23T10:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-24T09:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-25T08:00:07.html, with 5 events
# === DOCUMENT yale/events_2019-05-26T10:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-27T00:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-05-28T00:00:03.html, with 5 events
# === DOCUMENT yale/events_2019-05-29T03:00:08.html, with 5 events
# === DOCUMENT yale/events_2019-05-30T00:00:07.html, with 5 events
# === DOCUMENT yale/events_2019-05-31T05:00:03.html, with 5 events
# === DOCUMENT yale/events_2019-06-01T11:00:04.html, with 10 events
# parsing https://apps.admissions.yale.edu/portal/events?id=6add34d4-b3c6-4eb5-8d68-0ba093945391
# parsing https://apps.admissions.yale.edu/portal/events?id=736236b7-ca99-4085-bf8f-f69032cc37dd
# parsing https://apps.admissions.yale.edu/portal/events?id=702b8369-5af1-4a33-ad6b-8d284d51f859
# parsing https://apps.admissions.yale.edu/portal/events?id=67660d42-3cab-41a2-941c-7afbb92b7f52
# parsing https://apps.admissions.yale.edu/portal/events?id=1086a514-db4f-4eb9-9551-2cbd65db7c1c
# === DOCUMENT yale/events_2019-06-02T09:00:04.html, with 10 events
# === DOCUMENT yale/events_2019-06-03T00:00:04.html, with 9 events
# === DOCUMENT yale/events_2019-06-04T00:00:05.html, with 8 events
# === DOCUMENT yale/events_2019-06-05T09:00:04.html, with 7 events
# === DOCUMENT yale/events_2019-06-06T09:00:04.html, with 6 events
# === DOCUMENT yale/events_2019-06-07T00:00:07.html, with 5 events
# === DOCUMENT yale/events_2019-06-08T00:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-09T08:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-10T09:00:05.html, with 5 events
# === DOCUMENT yale/events_2019-06-11T09:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-12T09:00:06.html, with 5 events
# === DOCUMENT yale/events_2019-06-13T09:00:05.html, with 5 events
# === DOCUMENT yale/events_2019-06-14T02:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-15T00:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-16T10:00:08.html, with 5 events
# === DOCUMENT yale/events_2019-06-17T22:00:09.html, with 5 events
# === DOCUMENT yale/events_2019-06-18T08:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-19T00:00:05.html, with 5 events
# === DOCUMENT yale/events_2019-06-20T09:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-21T00:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-22T10:00:03.html, with 5 events
# === DOCUMENT yale/events_2019-06-23T00:00:04.html, with 5 events
# === DOCUMENT yale/events_2019-06-24T09:01:43.html, with 4 events
# === DOCUMENT yale/events_2019-06-25T01:00:03.html, with 3 events
# === DOCUMENT yale/events_2019-06-26T00:00:04.html, with 2 events
# === DOCUMENT yale/events_2019-06-28T12:00:03.html, with 0 events
# === DOCUMENT yale/events_2019-06-29T00:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-06-30T14:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-07-01T22:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-07-02T08:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-07-03T00:00:06.html, with 0 events
# === DOCUMENT yale/events_2019-07-07T10:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-07-09T23:00:12.html, with 0 events
# === DOCUMENT yale/events_2019-07-10T08:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-07-11T08:00:07.html, with 0 events
# === DOCUMENT yale/events_2019-07-12T23:00:05.html, with 0 events
# === DOCUMENT yale/events_2019-07-13T00:00:04.html, with 0 events
# === DOCUMENT yale/events_2019-07-14T00:00:06.html, with 0 events
# === DOCUMENT yale/events_2019-07-15T00:00:05.html, with 0 events
# === DOCUMENT yale/events_2019-07-16T00:00:03.html, with 0 events
# === DOCUMENT yale/events_2019-07-17T00:00:03.html, with 0 events
# === DOCUMENT yale/events_2019-07-18T00:00:03.html, with 0 events
# === DOCUMENT yale/events_2019-07-19T20:00:04.html, with 0 events

# %%
EVENTS_LIST = []

for key in EVENTS.keys():
    event = EVENTS[key]
    event['id'] = key
    EVENTS_LIST.append(event)

# %%
with open('../data/events-20190719.json', 'w') as f:
    f.write(json.dumps(EVENTS_LIST))
